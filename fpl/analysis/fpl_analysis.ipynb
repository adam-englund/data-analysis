# %%
import pandas as pd

# %%
df = pd.read_csv("../data/fpl_fbref_season_player_history.csv")
df.head()
# Out:
#    row_index  season_year_ending     season        division     team  \
# 0          0                2022  2021-2022  Premier League  Arsenal
# 1          2                2022  2021-2022  Premier League  Arsenal
# 2          4                2022  2021-2022  Premier League  Arsenal
# 3          5                2022  2021-2022  Premier League  Arsenal
# 4          6                2022  2021-2022  Premier League  Arsenal
#
#        player_name nationality position   age  games  ...  penalties_missed  \
# 0      Bukayo Saka         ENG    FW,MF  19.0     38  ...               0.0
# 1   Aaron Ramsdale         ENG       GK  23.0     34  ...               0.0
# 2  Martin Ødegaard         NOR       MF  22.0     36  ...               0.0
# 3     Granit Xhaka         SUI    MF,DF  28.0     27  ...               0.0
# 4    Thomas Partey         GHA       MF  28.0     24  ...               0.0
#
#    yellow_cards  red_cards  saves  bonus    bps  influence  creativity  \
# ...
